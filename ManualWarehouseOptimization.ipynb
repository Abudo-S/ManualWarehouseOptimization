# %%
import matplotlib.pyplot as plt
import pandas as pd
import importlib
from pyomo.environ import *
# %matplotlib inline

import MultiCriteriaMIPModel as MultiCriteriaMIPModel_Module
importlib.reload(MultiCriteriaMIPModel_Module) # in case of updates

from MultiCriteriaMIPModel import MultiCriteriaMIPModel

# %%
mcmModel= MultiCriteriaMIPModel()
instance, results = mcmModel.solve("Mip_parameters.dat")

# %%
mcmModel.display_solution(instance)
# Out:
# Model unknown
#
#   Variables:
#     y : Size=2, Index=I_max
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           A :     0 :   0.0 :     1 : False : False : Binary
#           B :     0 :   1.0 :     1 : False : False : Binary
#     z : Size=50, Index=I_max*J_prime*J_prime
#         Key         : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 0, 0) :     0 :  None :     1 : False :  True : Binary
#         ('A', 0, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 0, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 0, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 0, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 1, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 1, 1) :     0 :  None :     1 : False :  True : Binary
#         ('A', 1, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 1, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 1, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 2) :     0 :  None :     1 : False :  True : Binary
#         ('A', 2, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 3) :     0 :  None :     1 : False :  True : Binary
#         ('A', 3, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 4) :     0 :  None :     1 : False :  True : Binary
#         ('B', 0, 0) :     0 :  None :     1 : False :  True : Binary
#         ('B', 0, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 0, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 0, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 0, 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 1, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 1, 1) :     0 :  None :     1 : False :  True : Binary
#         ('B', 1, 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 1, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 1, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 2, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 2, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 2, 2) :     0 :  None :     1 : False :  True : Binary
#         ('B', 2, 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 2, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 3, 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 3, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 3, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 3, 3) :     0 :  None :     1 : False :  True : Binary
#         ('B', 3, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 4, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 4) :     0 :  None :     1 : False :  True : Binary
#     x : Size=8, Index=I_max*J
#         Key      : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 4) :     0 :   1.0 :     1 : False : False : Binary
#     S : Size=4, Index=J
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  24.0 :  None : False : False :  Reals
#           2 :     0 :  52.0 :  None : False : False :  Reals
#           3 :     0 :  67.0 :  None : False : False :  Reals
#           4 :     0 :   0.0 :  None : False : False :  Reals
#     C : Size=4, Index=J
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  49.0 :  None : False : False :  Reals
#           2 :     0 :  62.0 :  None : False : False :  Reals
#           3 :     0 :  87.0 :  None : False : False :  Reals
#           4 :     0 :  22.0 :  None : False : False :  Reals
#     S_first : Size=2, Index=I_max
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           A :     0 :  None :  None : False :  True :  Reals
#           B :     0 :  None :  None : False :  True :  Reals
#     C_last : Size=2, Index=I_max
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           A :     0 :   0.0 :  None : False : False :  Reals
#           B :     0 :  92.0 :  None : False : False :  Reals
#     Z : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :  92.0 :  None : False : False :  Reals
#
#   Objectives:
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 192.0
#
#   Constraints:
#     Sequencing : Size=24
#         Key         : Lower : Body     : Upper
#         ('A', 1, 2) :  None : -10000.0 :   0.0
#         ('A', 1, 3) :  None : -10011.0 :   0.0
#         ('A', 1, 4) :  None :  -9949.0 :   0.0
#         ('A', 2, 1) :  None :  -9959.0 :   0.0
#         ('A', 2, 3) :  None : -10000.0 :   0.0
#         ('A', 2, 4) :  None :  -9934.0 :   0.0
#         ('A', 3, 1) :  None :  -9930.0 :   0.0
#         ('A', 3, 2) :  None :  -9960.0 :   0.0
#         ('A', 3, 4) :  None :  -9904.0 :   0.0
#         ('A', 4, 1) :  None : -10000.0 :   0.0
#         ('A', 4, 2) :  None : -10026.0 :   0.0
#         ('A', 4, 3) :  None : -10036.0 :   0.0
#         ('B', 1, 2) :  None :      0.0 :   0.0
#         ('B', 1, 3) :  None : -10011.0 :   0.0
#         ('B', 1, 4) :  None :  -9949.0 :   0.0
#         ('B', 2, 1) :  None :  -9959.0 :   0.0
#         ('B', 2, 3) :  None :      0.0 :   0.0
#         ('B', 2, 4) :  None :  -9934.0 :   0.0
#         ('B', 3, 1) :  None :  -9930.0 :   0.0
#         ('B', 3, 2) :  None :  -9960.0 :   0.0
#         ('B', 3, 4) :  None :  -9904.0 :   0.0
#         ('B', 4, 1) :  None :      0.0 :   0.0
#         ('B', 4, 2) :  None : -10026.0 :   0.0
#         ('B', 4, 3) :  None : -10036.0 :   0.0
#     CompletionTime : Size=4
#         Key : Lower : Body : Upper
#           1 :   0.0 :  0.0 :   0.0
#           2 :   0.0 :  0.0 :   0.0
#           3 :   0.0 :  0.0 :   0.0
#           4 :   0.0 :  0.0 :   0.0
#     Assignment : Size=4
#         Key : Lower : Body : Upper
#           1 :   1.0 :  1.0 :   1.0
#           2 :   1.0 :  1.0 :   1.0
#           3 :   1.0 :  1.0 :   1.0
#           4 :   1.0 :  1.0 :   1.0
#     FlowInflowOutflow : Size=8
#         Key      : Lower : Body : Upper
#         ('A', 1) :   0.0 :  0.0 :   0.0
#         ('A', 2) :   0.0 :  0.0 :   0.0
#         ('A', 3) :   0.0 :  0.0 :   0.0
#         ('A', 4) :   0.0 :  0.0 :   0.0
#         ('B', 1) :   0.0 :  0.0 :   0.0
#         ('B', 2) :   0.0 :  0.0 :   0.0
#         ('B', 3) :   0.0 :  0.0 :   0.0
#         ('B', 4) :   0.0 :  0.0 :   0.0
#     FlowAssignment : Size=8
#         Key      : Lower : Body : Upper
#         ('A', 1) :   0.0 :  0.0 :   0.0
#         ('A', 2) :   0.0 :  0.0 :   0.0
#         ('A', 3) :   0.0 :  0.0 :   0.0
#         ('A', 4) :   0.0 :  0.0 :   0.0
#         ('B', 1) :   0.0 :  0.0 :   0.0
#         ('B', 2) :   0.0 :  0.0 :   0.0
#         ('B', 3) :   0.0 :  0.0 :   0.0
#         ('B', 4) :   0.0 :  0.0 :   0.0
#     BaseOutflow : Size=2
#         Key : Lower : Body : Upper
#           A :   0.0 :  0.0 :   0.0
#           B :   0.0 :  0.0 :   0.0
#     BaseInflow : Size=2
#         Key : Lower : Body : Upper
#           A :   0.0 :  0.0 :   0.0
#           B :   0.0 :  0.0 :   0.0
#     CLastDefinition : Size=8
#         Key      : Lower : Body     : Upper
#         ('A', 1) :  None :  -9945.0 :   0.0
#         ('A', 2) :  None :  -9934.0 :   0.0
#         ('A', 3) :  None :  -9908.0 :   0.0
#         ('A', 4) :  None :  -9971.0 :   0.0
#         ('B', 1) :  None : -10037.0 :   0.0
#         ('B', 2) :  None : -10026.0 :   0.0
#         ('B', 3) :  None :      0.0 :   0.0
#         ('B', 4) :  None : -10063.0 :   0.0
#     CapacityCheck : Size=2
#         Key : Lower : Body   : Upper
#           A :  None :    0.0 :   0.0
#           B :  None : -388.0 :   0.0
#     MakespanDefinition : Size=2
#         Key : Lower : Body  : Upper
#           A :  None : -92.0 :   0.0
#           B :  None :   0.0 :   0.0

# %%
solution_data = []
for i in instance.I_max:
    if value(instance.y[i]) == 1:
        #operator i is active
        for j in instance.J:
            #check for assigned tasks based on sequencing variable z
            for k in instance.J_prime:
                try:
                    var_instance = value(instance.z[i, j, k])
                except:
                    continue
                if value(var_instance) == 1 and j != 0 and k != 0:
                    # Task j is sequenced before k by operator i
                    solution_data.append({
                        'Operator': i,
                        'Task': j,
                        'Start': value(instance.S[j]),
                        'Finish': value(instance.C[j]),
                        'Successor': k
                    })

df_schedule = pd.DataFrame(solution_data)
df_schedule = df_schedule.sort_values(by=['Operator', 'Start']).reset_index(drop=True)
print(df_schedule)
# Out:
# ERROR: evaluating object as numeric value: z[B,1,1]
#         (object: <class 'pyomo.core.base.var.VarData'>)
#     No value for uninitialized VarData object z[B,1,1]
# ERROR: evaluating object as numeric value: z[B,2,2]
#         (object: <class 'pyomo.core.base.var.VarData'>)
#     No value for uninitialized VarData object z[B,2,2]
# ERROR: evaluating object as numeric value: z[B,3,3]
#         (object: <class 'pyomo.core.base.var.VarData'>)
#     No value for uninitialized VarData object z[B,3,3]
# ERROR: evaluating object as numeric value: z[B,4,4]
#         (object: <class 'pyomo.core.base.var.VarData'>)
#     No value for uninitialized VarData object z[B,4,4]
#   Operator  Task  Start  Finish  Successor
# 0        B     4    0.0    22.0          1
# 1        B     1   24.0    49.0          2
# 2        B     2   52.0    62.0          3
