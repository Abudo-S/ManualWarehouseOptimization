# %%
#download and install CBC solver
#%pip install pyomo-windows

# from pyomo_windows.solvers import DownloadSolvers
# downloader = DownloadSolvers()
# downloader.download_cbc()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import importlib
from pyomo.environ import *
# %matplotlib inline

import ParameterDataLoader as ParameterDataLoader_Module
import MultiCriteriaMIPModel as MultiCriteriaMIPModel_Module

importlib.reload(ParameterDataLoader_Module) # in case of updates
importlib.reload(MultiCriteriaMIPModel_Module) # in case of updates

from ParameterDataLoader import ParameterDataLoader
from MultiCriteriaMIPModel import MultiCriteriaMIPModel

H_FIXED_MINUTES = 480
ALPHA = 1.0 #makespan weight
BETA = 1.0 #Operator activation weight 
BIG_M = 10000

# %% [markdown]
# ### Load Mission Batch Datasets
# For now, we introduce some simplifications:
# - we don't consider the priority of mission, neither the area of mission.
# - we don't consider the operational area of forklift.
# - we don't consider the tare of mission's pallet (UDC).
# - since we don't consider the Z axis, so we have to suppose that the loading & unloading speeds are equal for all mission types; therefore, there's no need to consider them.
# - the travel time is calculated using forklift's overall average speed, not for each single forklift.
#
# *Mission types are {loading, unloading, internal repositioning}.

# %%
MISSION_BATCH_DIR = "./datasets/Batch100M_distanced.csv"
UDC_TYPES_DIR = "./datasets/WM_UDC_TYPE.csv"
MISSION_BATCH_TRAVEL_DIR = "./datasets/Batch100M_travel_distanced.csv"
FORK_LIFTS_DIR = "./datasets/ForkLifts.csv"
#MISSION_TYPES_DIR = "./datasets/MissionTypes.csv"

#with mission TP_UDC, we can retreive relative width and length from mission types
#mission_batch_features = ['CD_MISSION', 'TP_MISSION', 'FROM_X', 'FROM_Y', 'TO_X', 'TO_Y', 'TP_UDC', 'DISTANCE']
mission_batch_features = ['CD_MISSION', 'FROM_X', 'FROM_Y', 'TO_X', 'TO_Y', 'TP_UDC', 'DISTANCE']
udc_types_features = ['TP_UDC', 'WIDTH', 'LENGTH']
mission_batch_travel_features = ['CD_MISSION_1', 'CD_MISSION_2', 'FROM_X', 'FROM_Y', 'TO_X', 'TO_Y', 'DISTANCE']
#fork_lifts_features = ['OID', 'FORK_WIDTH', 'FORK_LEGNTH', 'SPEED', 'SPEED_WITH_LOAD', 'UP_SPEED', 'UP_SPEED_WITH_LOAD', 'DOWN_SPEED', 'DOWN_SPEED_WITH_LOAD']
fork_lifts_features = ['OID', 'FORK_WIDTH', 'FORK_LEGNTH', 'SPEED', 'SPEED_WITH_LOAD']
#mission_types_features = ['TP_MISSION', 'DSC_MISSION']

mission_batch_df = pd.read_csv(MISSION_BATCH_DIR)[mission_batch_features]
udc_types_df = pd.read_csv(UDC_TYPES_DIR)[udc_types_features]
mission_batch_travel_df = pd.read_csv(MISSION_BATCH_TRAVEL_DIR)[mission_batch_travel_features]
fork_lifts_df = pd.read_csv(FORK_LIFTS_DIR)[fork_lifts_features]
#mission_types_df = pd.read_csv(MISSION_TYPES_DIR)[mission_types_features]

mission_batch_df.head()
# Out:
#    CD_MISSION  FROM_X  FROM_Y  TO_X  TO_Y  TP_UDC  DISTANCE
# 0     3911722     246     426   194   373     1.0        59
# 1     3911727     246     426   194   373     1.0        59
# 2     3911733     246     426   194   373     1.0        59
# 3     3911740     262     329   194   373     1.0       103
# 4     3911742     246     426   194   373     1.0        59

# %%
udc_types_df.head()
# Out:
#    TP_UDC  WIDTH  LENGTH
# 0       8   1.05    1.05
# 1      13   1.23    1.43
# 2      14   1.74    1.83
# 3      15   0.75    1.70
# 4      16   0.75    2.50

# %% [markdown]
# ##### Mission feature units
# - distance, width and length in meter.
# Note that the distance is already pre-calculated using external program by applying A* on features {FORM_X, FROM_Y, TO_X, TO_Y}. The external progam has considered an image that describe the real-world warehouse map, then the path is estimated by A* after scaling image's pixels to calculate the distance approximately.
#
# *A future efficient approach could be through saving the warehouse map on a geografic system exploiting GIS queries for distance and path calculations.

# %%
BASE_MISSION = [0, 0, 0, 0, 0, 0, 0, 0]  #virtual base mission for operators to start and end their routes

mission_batch_df.TP_UDC.fillna(1, inplace=True)
mission_batch_df = pd.merge(mission_batch_df, udc_types_df, on='TP_UDC')
mission_batch_df.drop(columns=['TP_UDC'], inplace=True)
mission_batch_df_with_base = pd.concat([pd.DataFrame([BASE_MISSION], columns=mission_batch_df.columns), mission_batch_df], ignore_index=True)
mission_batch_df.head()
# Out:
# C:\Users\abudo\AppData\Local\Temp\ipykernel_17568\408980915.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mission_batch_df.TP_UDC.fillna(1, inplace=True)
#    CD_MISSION  FROM_X  FROM_Y  TO_X  TO_Y  DISTANCE  WIDTH  LENGTH
# 0     3911722     246     426   194   373        59    0.8     1.2
# 1     3911727     246     426   194   373        59    0.8     1.2
# 2     3911733     246     426   194   373        59    0.8     1.2
# 3     3911740     262     329   194   373       103    0.8     1.2
# 4     3911742     246     426   194   373        59    0.8     1.2

# %%
mission_batch_travel_df.head()
# Out:
#    CD_MISSION_1  CD_MISSION_2  FROM_X  FROM_Y  TO_X  TO_Y  DISTANCE
# 0       3911722       3911727     194     373   246   426        59
# 1       3911727       3911722     194     373   246   426        59
# 2       3911722       3911733     194     373   246   426        59
# 3       3911733       3911722     194     373   246   426        59
# 4       3911722       3911740     194     373   262   329        99

# %% [markdown]
# ##### Fork Lift feature units
# - width & length in meter.
# - speed in meter/minute.

# %%
fork_lifts_df.head()
# Out:
#    OID  FORK_WIDTH  FORK_LEGNTH  SPEED  SPEED_WITH_LOAD
# 0    1         1.1          1.7  300.0            300.0
# 1    2         1.1          1.7  300.0            300.0
# 2    3         1.1          1.7  300.0            300.0
# 3    4         1.1          1.7  300.0            300.0
# 4    5         1.1          1.7  300.0            300.0

# %%
parameter_data_loader = ParameterDataLoader(
    mission_batch_df,
    mission_batch_travel_df,
    fork_lifts_df
)

processing_times = parameter_data_loader.get_mission_processing_times()
travel_times = parameter_data_loader.get_mission_travel_times()
skill_scores = parameter_data_loader.get_operator_skill_scores()

# %%
mcmModel= MultiCriteriaMIPModel(mission_batch_df.CD_MISSION.to_list(),
                                 fork_lifts_df.OID.to_list(),
                                 mission_batch_df_with_base.CD_MISSION.to_list(),
                                 processing_times,
                                 travel_times,
                                 skill_scores,
                                 H_FIXED_MINUTES,
                                 ALPHA,
                                 BETA,
                                 BIG_M
                                )

#instance, results = mcmModel.solve("Mip_parameters.dat", "cbc")
#instance, results = mcmModel.solve("Mip_parameters.dat")
# Out:
# WARNING: DEPRECATED: The 'concrete' attribute is no longer supported.  Use
# isdiscrete() or isfinite()  (deprecated in 5.7) (called from
# C:\Users\abudo\AppData\Roaming\Python\Python313\site-
# packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_resolver.py:193)
# WARNING: DEPRECATED: 'filter' is no longer a public attribute.  (deprecated in
# 5.7) (called from C:\Users\abudo\AppData\Roaming\Python\Python313\site-
# packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_resolver.py:193)
# WARNING: DEPRECATED: The 'ordered' attribute is no longer supported.  Use
# isordered()  (deprecated in 5.7) (called from
# C:\Users\abudo\AppData\Roaming\Python\Python313\site-
# packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_resolver.py:193)
# WARNING: DEPRECATED: The 'value' attribute is deprecated.  Use .data() to
# retrieve the values in a finite set.  (deprecated in 5.7) (called from
# C:\Users\abudo\AppData\Roaming\Python\Python313\site-
# packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_resolver.py:193)
# WARNING: DEPRECATED: The 'value_list' attribute is deprecated.  Use
# .ordered_data() to retrieve the values from a finite set in a deterministic
# order.  (deprecated in 5.7) (called from
# C:\Users\abudo\AppData\Roaming\Python\Python313\site-
# packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_resolver.py:193)
# WARNING: DEPRECATED: The 'virtual' attribute is no longer supported
# (deprecated in 5.7) (called from
# C:\Users\abudo\AppData\Roaming\Python\Python313\site-
# packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_resolver.py:193)
# ERROR: Rule failed when generating expression for Objective Objective with
# index None: ValueError: Error retrieving immutable Param value (Alpha):
#             The Param value is undefined and no default value is specified.
# ERROR: Constructing component 'Objective' from data=None failed:
#         ValueError: Error retrieving immutable Param value (Alpha):
#     	The Param value is undefined and no default value is specified.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[254], line 1
# ----> 1 mcmModel= MultiCriteriaMIPModel(mission_batch_df.CD_MISSION.to_list(),
#       2                                  fork_lifts_df.OID.to_list(),
#       3                                  mission_batch_df.CD_MISSION.to_list()
#       4                                 )
#       5 #data_portal = parameter_data_loader.get_data_portal(mcmModel.model)
#       6 #instance, results = mcmModel.solve("Mip_parameters.dat", "cbc")
#       7 #instance, results = mcmModel.solve("Mip_parameters.dat")
#
# File c:\Users\abudo\source\vscode_projects\ManualWarehouseOptimization\MultiCriteriaMIPModel.py:63, in MultiCriteriaMIPModel.__init__(self, missions, operators, missions_with_base)
#      57     '''
#      58     Multi-criteria objective function: minimize weighted sum of makespan and number of operators used.
#      59     Total Weighted Score = (alpha * makespan) + (beta * total activated operators)
#      60     '''
#      61     return model.Alpha * model.Z + model.Beta * sum(model.y[i] for i in model.I_max)
# ---> 63 model.Objective = Objective(rule=objective_rule, sense=minimize)
#      65 #Constraints
#      66 #scheduling and time constraints
#      67 def completion_time_rule(model, j):
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\block.py:573, in BlockData.__setattr__(self, name, val)
#     568 if name not in self.__dict__:
#     569     if isinstance(val, Component):
#     570         #
#     571         # Pyomo components are added with the add_component method.
#     572         #
# --> 573         self.add_component(name, val)
#     574     else:
#     575         #
#     576         # Other Python objects are added with the standard __setattr__
#     577         # method.
#     578         #
#     579         super(BlockData, self).__setattr__(name, val)
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\block.py:1103, in BlockData.add_component(self, name, val)
#    1095     logger.debug(
#    1096         "Constructing %s '%s' on %s from data=%s",
#    1097         val.__class__.__name__,
#    (...)   1100         str(data),
#    1101     )
#    1102 try:
# -> 1103     val.construct(data)
#    1104 except:
#    1105     err = sys.exc_info()[1]
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\disable_methods.py:124, in disable_methods.<locals>.class_decorator.<locals>.construct(self, data)
#     122     self._name = base.__name__
#     123 self.__class__ = base
# --> 124 return base.construct(self, data)
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\objective.py:360, in Objective.construct(self, data)
#     358 # Bypass the index validation and create the member directly
#     359 for index in self.index_set():
# --> 360     ans = self._setitem_when_not_present(index, rule(block, index))
#     361     if ans is not None:
#     362         ans.set_sense(self._init_sense(block, index))
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\initializer.py:485, in ScalarCallInitializer.__call__(self, parent, idx, **kwargs)
#     484 def __call__(self, parent, idx, **kwargs):
# --> 485     return self._fcn(parent, **kwargs)
#
# File c:\Users\abudo\source\vscode_projects\ManualWarehouseOptimization\MultiCriteriaMIPModel.py:61, in MultiCriteriaMIPModel.__init__.<locals>.objective_rule(model)
#      56 def objective_rule(model):
#      57     '''
#      58     Multi-criteria objective function: minimize weighted sum of makespan and number of operators used.
#      59     Total Weighted Score = (alpha * makespan) + (beta * total activated operators)
#      60     '''
# ---> 61     return model.Alpha * model.Z + model.Beta * sum(model.y[i] for i in model.I_max)
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\expr\numeric_expr.py:476, in NumericValue.__mul__(self, other)
#     468 def __mul__(self, other):
#     469     """
#     470     Binary multiplication
#     471
#    (...)    474         self * other
#     475     """
# --> 476     return _mul_dispatcher[self.__class__, other.__class__](self, other)
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\expr\numeric_expr.py:2972, in _register_new_mul_handler(a, b)
#    2968 _mul_dispatcher[a.__class__, b.__class__] = handler = _mul_type_handler_mapping[
#    2969     types
#    2970 ]
#    2971 # Call the appropriate handler
# -> 2972 return handler(a, b)
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\expr\numeric_expr.py:2708, in _mul_param_var(a, b)
#    2706 def _mul_param_var(a, b):
#    2707     if a.is_constant():
# -> 2708         a = a.value
#    2709         if a in _zero_one_optimizations:
#    2710             return b if a else 0
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\param.py:230, in ParamData.value(self)
#     227 @property
#     228 def value(self):
#     229     """Return the value for this variable."""
# --> 230     return self()
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\param.py:969, in ScalarParam.__call__(self, exception)
#     965             self[None]
#     966         else:
#     967             # Immutable Param defaults never get added to the
#     968             # _data dict
# --> 969             return self[None]
#     970     return super(ScalarParam, self).__call__(exception=exception)
#     971 if exception:
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\indexed_component.py:662, in IndexedComponent.__getitem__(self, index)
#     657     #
#     658     # Call the _getitem_when_not_present helper to retrieve/return
#     659     # the default value
#     660     #
#     661     if obj is _NotFound:
# --> 662         return self._getitem_when_not_present(index)
#     664 return obj
#
# File c:\Users\abudo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyomo\core\base\param.py:646, in Param._getitem_when_not_present(self, index)
#     644     else:
#     645         idx_str = '%s' % (self.name,)
# --> 646     raise ValueError(
#     647         "Error retrieving immutable Param value (%s):\n\tThe Param "
#     648         "value is undefined and no default value is specified." % (idx_str,)
#     649     )
#     651 _default_type = type(val)
#     652 _check_value_domain = True
#
# ValueError: Error retrieving immutable Param value (Alpha):
# 	The Param value is undefined and no default value is specified.

# %%
mcmModel.display_solution(instance)
# Out:
# Model unknown
#
#   Variables:
#     y : Size=2, Index=I_max
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           A :     0 :   1.0 :     1 : False : False : Binary
#           B :     0 :   1.0 :     1 : False : False : Binary
#     z : Size=50, Index=I_max*J_prime*J_prime
#         Key         : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 0, 0) :     0 :  None :     1 : False :  True : Binary
#         ('A', 0, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 0, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 0, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 0, 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('A', 1, 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('A', 1, 1) :     0 :  None :     1 : False :  True : Binary
#         ('A', 1, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 1, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 1, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 2) :     0 :  None :     1 : False :  True : Binary
#         ('A', 2, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 2, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3, 3) :     0 :  None :     1 : False :  True : Binary
#         ('A', 3, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('A', 4, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4, 4) :     0 :  None :     1 : False :  True : Binary
#         ('B', 0, 0) :     0 :  None :     1 : False :  True : Binary
#         ('B', 0, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 0, 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 0, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 0, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 1, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 1, 1) :     0 :  None :     1 : False :  True : Binary
#         ('B', 1, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 1, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 1, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 2, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 2, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 2, 2) :     0 :  None :     1 : False :  True : Binary
#         ('B', 2, 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 2, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 3, 0) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 3, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 3, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 3, 3) :     0 :  None :     1 : False :  True : Binary
#         ('B', 3, 4) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 0) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 4, 4) :     0 :  None :     1 : False :  True : Binary
#     x : Size=8, Index=I_max*J
#         Key      : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 1) :     0 :   1.0 :     1 : False : False : Binary
#         ('A', 2) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 3) :     0 :   0.0 :     1 : False : False : Binary
#         ('A', 4) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 1) :     0 :   0.0 :     1 : False : False : Binary
#         ('B', 2) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 3) :     0 :   1.0 :     1 : False : False : Binary
#         ('B', 4) :     0 :   0.0 :     1 : False : False : Binary
#     S : Size=4, Index=J
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  20.0 :  None : False : False :  Reals
#           2 :     0 :   0.0 :  None : False : False :  Reals
#           3 :     0 :  15.0 :  None : False : False :  Reals
#           4 :     0 :   0.0 :  None : False : False :  Reals
#     C : Size=4, Index=J
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  40.0 :  None : False : False :  Reals
#           2 :     0 :  10.0 :  None : False : False :  Reals
#           3 :     0 :  35.0 :  None : False : False :  Reals
#           4 :     0 :  18.0 :  None : False : False :  Reals
#     S_first : Size=2, Index=I_max
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           A :     0 :  None :  None : False :  True :  Reals
#           B :     0 :  None :  None : False :  True :  Reals
#     C_last : Size=2, Index=I_max
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           A :     0 :  46.0 :  None : False : False :  Reals
#           B :     0 :  46.0 :  None : False : False :  Reals
#     Z : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :  46.0 :  None : False : False :  Reals
#
#   Objectives:
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True :  46.0
#
#   Constraints:
#     Sequencing : Size=24
#         Key         : Lower : Body     : Upper
#         ('A', 1, 2) :  None :  -9957.0 :   0.0
#         ('A', 1, 3) :  None :  -9968.0 :   0.0
#         ('A', 1, 4) :  None :  -9958.0 :   0.0
#         ('A', 2, 1) :  None : -10007.0 :   0.0
#         ('A', 2, 3) :  None : -10000.0 :   0.0
#         ('A', 2, 4) :  None :  -9986.0 :   0.0
#         ('A', 3, 1) :  None :  -9978.0 :   0.0
#         ('A', 3, 2) :  None :  -9960.0 :   0.0
#         ('A', 3, 4) :  None :  -9956.0 :   0.0
#         ('A', 4, 1) :  None :      0.0 :   0.0
#         ('A', 4, 2) :  None :  -9978.0 :   0.0
#         ('A', 4, 3) :  None :  -9988.0 :   0.0
#         ('B', 1, 2) :  None :  -9957.0 :   0.0
#         ('B', 1, 3) :  None :  -9968.0 :   0.0
#         ('B', 1, 4) :  None :  -9958.0 :   0.0
#         ('B', 2, 1) :  None : -10007.0 :   0.0
#         ('B', 2, 3) :  None :      0.0 :   0.0
#         ('B', 2, 4) :  None :  -9986.0 :   0.0
#         ('B', 3, 1) :  None :  -9978.0 :   0.0
#         ('B', 3, 2) :  None :  -9960.0 :   0.0
#         ('B', 3, 4) :  None :  -9956.0 :   0.0
#         ('B', 4, 1) :  None : -10000.0 :   0.0
#         ('B', 4, 2) :  None :  -9978.0 :   0.0
#         ('B', 4, 3) :  None :  -9988.0 :   0.0
#     CompletionTime : Size=4
#         Key : Lower : Body : Upper
#           1 :   0.0 :  0.0 :   0.0
#           2 :   0.0 :  0.0 :   0.0
#           3 :   0.0 :  0.0 :   0.0
#           4 :   0.0 :  0.0 :   0.0
#     Assignment : Size=4
#         Key : Lower : Body : Upper
#           1 :   1.0 :  1.0 :   1.0
#           2 :   1.0 :  1.0 :   1.0
#           3 :   1.0 :  1.0 :   1.0
#           4 :   1.0 :  1.0 :   1.0
#     FlowInflowOutflow : Size=8
#         Key      : Lower : Body : Upper
#         ('A', 1) :   0.0 :  0.0 :   0.0
#         ('A', 2) :   0.0 :  0.0 :   0.0
#         ('A', 3) :   0.0 :  0.0 :   0.0
#         ('A', 4) :   0.0 :  0.0 :   0.0
#         ('B', 1) :   0.0 :  0.0 :   0.0
#         ('B', 2) :   0.0 :  0.0 :   0.0
#         ('B', 3) :   0.0 :  0.0 :   0.0
#         ('B', 4) :   0.0 :  0.0 :   0.0
#     FlowAssignment : Size=8
#         Key      : Lower : Body : Upper
#         ('A', 1) :   0.0 :  0.0 :   0.0
#         ('A', 2) :   0.0 :  0.0 :   0.0
#         ('A', 3) :   0.0 :  0.0 :   0.0
#         ('A', 4) :   0.0 :  0.0 :   0.0
#         ('B', 1) :   0.0 :  0.0 :   0.0
#         ('B', 2) :   0.0 :  0.0 :   0.0
#         ('B', 3) :   0.0 :  0.0 :   0.0
#         ('B', 4) :   0.0 :  0.0 :   0.0
#     BaseOutflow : Size=2
#         Key : Lower : Body : Upper
#           A :   0.0 :  0.0 :   0.0
#           B :   0.0 :  0.0 :   0.0
#     BaseInflow : Size=2
#         Key : Lower : Body : Upper
#           A :   0.0 :  0.0 :   0.0
#           B :   0.0 :  0.0 :   0.0
#     CLastDefinition : Size=8
#         Key      : Lower : Body     : Upper
#         ('A', 1) :  None :      0.0 :   0.0
#         ('A', 2) :  None : -10032.0 :   0.0
#         ('A', 3) :  None : -10006.0 :   0.0
#         ('A', 4) :  None : -10021.0 :   0.0
#         ('B', 1) :  None : -10000.0 :   0.0
#         ('B', 2) :  None : -10032.0 :   0.0
#         ('B', 3) :  None :     -6.0 :   0.0
#         ('B', 4) :  None : -10021.0 :   0.0
#     CapacityCheck : Size=2
#         Key : Lower : Body   : Upper
#           A :  None : -434.0 :   0.0
#           B :  None : -434.0 :   0.0
#     MakespanDefinition : Size=2
#         Key : Lower : Body : Upper
#           A :  None :  0.0 :   0.0
#           B :  None :  0.0 :   0.0

# %%
solution_data = []
for i in instance.I_max:
    if value(instance.y[i]) == 1: #in case of unfeasible solution, it launches a pyomo error
        #operator i is active
        for j in instance.J_prime:
            for k in instance.J_prime:
                
                #apply the j != k filter to avoid pyomo warning about self-loops
                if j != k:
                    #check if the index (i, j, k) is valid and exists in z
                    if (i, j, k) in instance.z:
                        
                        #check for active flow
                        if value(instance.z[i, j, k]) > 0.5:
                            
                            #add data only for flow between service orders (not flow to/from Base)
                            if j in instance.J and k in instance.J:
                                solution_data.append({
                                    'Operator': i,
                                    'Task': j,
                                    'Start': value(instance.S[j]),
                                    'Finish': value(instance.C[j]),
                                    'Successor': k
                                })

df_schedule = pd.DataFrame(solution_data)
df_schedule = df_schedule.sort_values(by=['Operator', 'Start']).reset_index(drop=True)
print(df_schedule)
# Out:
#   Operator  Task  Start  Finish  Successor
# 0        A     4    0.0    18.0          1
# 1        B     2    0.0    10.0          3

# %%
routes = {} 
    
# Check for solution status (optional but recommended)
# if not (results.solver.status == SolverStatus.ok and results.solver.termination_condition == TerminationCondition.optimal):
#     print("Solver did not find an optimal solution.")
#     return

# Call the function with your solved instance
# print_optimal_routes(instance)

# 1. Iterate over all potential operators
for i in instance.I_max:
    if value(instance.y[i]) < 0.5: #in case of unfeasible solution, it launches a pyomo error
        continue #skip unactivated operators

    print(f"\n--- Operator {i} (Activated) ---")

    current_node = 0  # Start at the Base node
    route_sequence = []
    is_route_complete = False

    #security counter to prevent infinite loops (should not happen if flow constraints are correct)
    max_steps = len(instance.J) + 2 
    steps = 0

    #loop until the route returns to the Base (k=0)
    while not is_route_complete and steps < max_steps:
        steps += 1
        
        #search for the next step (k) starting from the current node (current_node)
        found_next_step = False
        for k in instance.J_prime:
            if current_node == k:
                continue # Skip self-loop
            
            try:
                #check if the arc (current_node -> k) is active
                if value(instance.z[i, current_node, k]) > 0.5:
                    
                    #calculate travel time for printing
                    travel_time = value(instance.T[current_node, k])
                    
                    #handle Movement Types
                    if k == 0:
                        #final movement: Return to Base
                        route_sequence.append(f"-> Base (Arc: {current_node} -> 0 | Travel: {travel_time:.2f})")
                        is_route_complete = True
                        break #exit the k loop
                    else:
                        #service movement: j -> k
                        start_time = value(instance.S[k])
                        finish_time = value(instance.C[k])
                        proc_time = finish_time - start_time
                        
                        movement_detail = (
                            f"-> Order {k} | Travel: {travel_time:.2f} | Start: {start_time:.2f} | "
                            f"Proc: {proc_time:.2f} | Finish: {finish_time:.2f}"
                        )
                        route_sequence.append(movement_detail)
                        
                        #move to the next node in the sequence
                        current_node = k
                        found_next_step = True
                        break #exit the k loop
                        
            except KeyError:
                #this node pair might not exist in the defined set of z variables (e.g., if filtered by a complex index)
                continue

        if not found_next_step and not is_route_complete:
            print(f"Error: Route stopped unexpectedly at node {current_node} for operator {i}.")
            break
        
    #print the final sequenced route for the operator
    route_string = "\n".join(route_sequence)
    print("Path: Base " + route_string)
    print(f"Total Time (C_last): {value(instance.C_last[i]):.2f}")
    print("-" * 40)
# Out:
# --- Operator A (Activated) ---
# Path: Base -> Order 4 | Travel: 7.00 | Start: 0.00 | Proc: 18.00 | Finish: 18.00
# -> Order 1 | Travel: 2.00 | Start: 20.00 | Proc: 20.00 | Finish: 40.00
# -> Base (Arc: 1 -> 0 | Travel: 6.00)
# Total Time (C_last): 46.00
# ----------------------------------------
#
# --- Operator B (Activated) ---
# Path: Base -> Order 2 | Travel: 8.00 | Start: 0.00 | Proc: 10.00 | Finish: 10.00
# -> Order 3 | Travel: 5.00 | Start: 15.00 | Proc: 20.00 | Finish: 35.00
# -> Base (Arc: 3 -> 0 | Travel: 5.00)
# Total Time (C_last): 46.00
# ----------------------------------------
